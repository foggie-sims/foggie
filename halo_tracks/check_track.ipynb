# %%
import numpy as np

from astropy.table import Table
from astropy.io import ascii

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.size'] = 16.

# %matplotlib notebook

# %%
track = Table.read('nref11n_selfshield_15/track.dat', format='ascii.fixed_width_two_line')

# %%
fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111)
ax.step(track['redshift'], track['x0'])
plt.xlim((1.95, 6.2))
# Out:
# <img src="data:image/png;base64,..." width="900">
# (1.95, 6.2)

# %%
fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111)
ax.step(track['redshift'], track['x0'], label="x")
ax.step(track['redshift'], track['y0'], label="y")
ax.step(track['redshift'], track['z0'], label="z")
plt.legend()
plt.xlim((1.95, 6.2))
# Out:
# <img src="data:image/png;base64,..." width="900">
# (1.95, 6.2)

# %%
plt.step(track['redshift'], track['z0'])
plt.xlim((1.95,6.2))
# Out:
# (1.95, 6.2)

# %%
## try to calculate the difference
dr = np.zeros(len(track))
for i in range(len(track)-1):
    dr[i] = np.sqrt((track['x0'][i+1]-track['x0'][i])**2 
                 + (track['y0'][i+1]-track['y0'][i])**2 
                 + (track['z0'][i+1]-track['z0'][i])**2)

# %%
fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111)
ax.step(track['redshift'], dr*100*1000)
plt.ylim(0,5)
plt.xlim((1.9, 6))
# Out:
# <img src="data:image/png;base64,..." width="900">
# (1.9, 6)

# %%
track[200:240]
# Out:
# <Table length=40>
#    redshift         x0             y0             z0        name
#    float64       float64        float64        float64      str6
# ------------- -------------- -------------- -------------- ------
# 2.87428914139 0.494961738586 0.491686820984 0.501170158386 DD0293
# 2.88046048351 0.494956016541  0.49169254303 0.501175880432 DD0292
# 2.88665584942 0.495036125183 0.491709709167 0.501173973083 DD0291
# 2.89287539095 0.494950294495 0.491702079773 0.501189231873 DD0290
# 2.89911926126 0.494950294495 0.491707801819 0.501194953918 DD0289
# 2.90538761486 0.494952201843 0.491713523865 0.501198768616 DD0288
#  2.9116806076  0.49506855011 0.491814613342  0.50110912323 DD0287
# 2.91799839668 0.494957923889 0.491728782654 0.501208305359 DD0286
# 2.92434114071 0.494961738586 0.491736412048 0.501212120056 DD0285
# 2.93070899968 0.494965553284 0.491744041443 0.501215934753 DD0284
#           ...            ...            ...            ...    ...
# ...

# %%
new_track = Table.read('nref11n_selfshield_15/track_temp.dat', format='ascii.fixed_width_two_line')
new_dr = np.zeros(len(new_track))
for i in range(len(new_track)-1):
    new_dr[i] = np.sqrt((new_track['x0'][i+1]-new_track['x0'][i])**2 
                 + (new_track['y0'][i+1]-new_track['y0'][i])**2 
                 + (new_track['z0'][i+1]-new_track['z0'][i])**2)

# %%
fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111)
ax.step(new_track['redshift'], new_dr*100*1000)
plt.ylim(0,5)
plt.xlim((3, 6.2))
# Out:
# (3, 6.2)

# %%
fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111)
ax.step(new_track['redshift'], new_track['z0'])
plt.xlim((2.68, 6.2))
# plt.ylim((0.494,0.497))
# plt.ylim((0.494,0.498))
plt.ylim((0.5005,0.5015))
# Out:
# (0.5005, 0.5015)
