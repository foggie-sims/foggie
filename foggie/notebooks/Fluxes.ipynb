# %%
# Quick flux tracking analysis for the nref11n run at z = 2
import yt
import numpy as np 

import os
os.sys.path.insert(0, '/Users/molly/Dropbox/foggie/foggie')
import get_halo_center as gc
from yt.funcs import mylog
mylog.setLevel(40) # This sets the log level to "ERROR"

# %%
ds = yt.load('/Users/molly/foggie/halo_008508/nref11n/natural/RD0020/RD0020')

# %%
center_guess = [0.494032,  0.488924,  0.502169]
halo_center, center_vel = gc.get_halo_center(ds, center_guess)
# Out:
# Parsing Hierarchy : 100%|██████████| 1449/1449 [00:00<00:00, 25125.66it/s]
# We have located the main halo at : [0.4940328598022461, 0.4889516830444336, 0.5021543502807617]

# %%
#s = ds.sphere(halo_center, radius=(5000,'kpc')) 
box = ds.r[0.49403285980224609-0.004:0.49403285980224609+0.004,0.48895168304443359-0.004:0.48895168304443359+0.004,0.50215435028076172-0.004:0.50215435028076172+0.004]

# %%
for radius in (np.arange(20)+1.) * 5.:
    surface = ds.surface(box, 'radius', (radius, 'kpc')) 
    mass_flux = surface.calculate_flux("velocity_x", "velocity_y", "velocity_z", "metal_density")
    s_l_flux = surface.calculate_flux("velocity_x", "velocity_y", "velocity_z", "specific_angular_momentum_magnitude")
    l_flux = surface.calculate_flux("velocity_x", "velocity_y", "velocity_z", "angular_momentum_magnitude")
    print(radius, mass_flux, l_flux, s_l_flux)
# Out:
# (5.0, 8.210416977628327e+24 g/s, 1.3036482615212822e+148 cm**5*g/s**2, 3.898822327078034e+112 cm**5/s**2)
# (10.0, 6.442338024453271e+21 g/s, -1.8572054556883086e+150 cm**5*g/s**2, 2.443997892801203e+112 cm**5/s**2)
# (15.0, -1.541497234535524e+22 g/s, -4.802823064233279e+150 cm**5*g/s**2, 3.184334585623381e+112 cm**5/s**2)
# (20.0, 6.386371804722018e+22 g/s, -1.0567432504022327e+151 cm**5*g/s**2, 5.245136603120299e+112 cm**5/s**2)
# (25.0, 1.3602101490469307e+23 g/s, -1.2218326917181446e+151 cm**5*g/s**2, 7.0050236150506875e+112 cm**5/s**2)
# (30.0, -2.264806287590404e+23 g/s, -8.513883232227271e+150 cm**5*g/s**2, 1.1630895236364203e+113 cm**5/s**2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-63b2621d74e4> in <module>()
#       2     surface = ds.surface(box, 'radius', (radius, 'kpc'))
# ...
