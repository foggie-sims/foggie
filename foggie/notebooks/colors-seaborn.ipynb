# %%
# %matplotlib inline
import seaborn as sns
sns.palplot(sns.color_palette("cubehelix", 20))

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
sns.palplot(sns.hls_palette(8, l=.3, s=.8))
sns.palplot(sns.hls_palette(8, l=.5, s=.8))
sns.palplot(sns.hls_palette(8, l=.7, s=.8))
sns.palplot(sns.hls_palette(8, l=.3, s=.2))
sns.palplot(sns.hls_palette(8, l=.5, s=.5))
sns.palplot(sns.hls_palette(8, l=.7, s=.8))

# %%
sns.palplot(sns.husl_palette(10, l=.5, s=0.6))

# %%
sns.choose_colorbrewer_palette('q')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-6830d112d43d> in <module>()
# ----> 1 sns.choose_colorbrewer_palette('q')
#
# /Users/molly/anaconda2/envs/astroconda/lib/python2.7/site-packages/seaborn/widgets.pyc in choose_colorbrewer_palette(data_type, as_cmap)
#     139                 "Pastel1", "Pastel2", "Dark2"]
#     140
# --> 141         @interact
#     142         def choose_qualitative(name=opts, n=(2, 16),
#     143                                desat=FloatSlider(min=0, max=1, value=1)):
#
# NameError: global name 'interact' is not defined

# %%
sns.palplot(sns.color_palette("cubehelix", 20))
sns.palplot(sns.cubehelix_palette(20, start=.5, dark=0, light=0.95, rot=1))

# %%
s, l = 90, 60
sns.palplot(sns.diverging_palette(359, 300, s=s, l=l, n=9))
sns.palplot(sns.diverging_palette(300, 240, s=s, l=l, n=9, center="dark"))
sns.palplot(sns.diverging_palette(240, 180, s=s, l=l, n=9, center="dark"))
sns.palplot(sns.diverging_palette(180, 120, s=s, l=l, n=9, center="dark"))
sns.palplot(sns.diverging_palette(120, 60, s=s, l=l, n=9, center="dark"))
sns.palplot(sns.diverging_palette(60, 0, s=s, l=l, n=9, center="dark"))

# %%
sns.choose_cubehelix_palette()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-9593ee732f0a> in <module>()
# ----> 1 sns.choose_cubehelix_palette()
#
# /Users/molly/anaconda2/envs/astroconda/lib/python2.7/site-packages/seaborn/widgets.pyc in choose_cubehelix_palette(as_cmap)
#     409         cmap = _init_mutable_colormap()
#     410
# --> 411     @interact
#     412     def choose_cubehelix(n_colors=IntSlider(min=2, max=16, value=9),
#     413                          start=FloatSlider(min=0, max=3, value=0),
#
# NameError: global name 'interact' is not defined

# %%
sns.palplot(sns.blend_palette(("red", "orange", "yellow","darkgreen","blue","purple"), n_colors=50))

# %%
sns.palplot(sns.blend_palette(("#d73027","darkorange","#ffe34d","#4daf4a","#4575b4","#984ea3"), n_colors=6),size=2)
sns.palplot(sns.blend_palette(("#d73027","darkorange","#ffe34d","#4daf4a","#4575b4","#984ea3"), n_colors=10),size=1.5)
sns.palplot(sns.blend_palette(("#d73027","darkorange","#ffe34d","#4daf4a","#4575b4","#984ea3"), n_colors=20))
sns.palplot(sns.blend_palette(("#d73027","darkorange","#ffe34d","#4daf4a","#4575b4","#984ea3"), n_colors=50))

# %%
sns.palplot(sns.blend_palette(("black","#d73027","darkorange","#ffe34d"), n_colors=50))
sns.palplot(sns.blend_palette(("black","#984ea3","#4575b4","#4daf4a","#ffe34d"), n_colors=50))

# %%
sns.palplot(sns.blend_palette(("black","#d73027","darkorange","#ffe34d","white"), n_colors=60))
sns.palplot(sns.blend_palette(("black","#984ea3","#4575b4","#4daf4a","#ffe34d","white"), n_colors=60))

# %%
sns.palplot(sns.dark_palette("#ffff90", n_colors=10),size=1.5)
sns.palplot(sns.dark_palette("#ffee90", n_colors=10),size=1.5)
sns.palplot(sns.dark_palette("#ffd700", n_colors=10),size=1.5)
sns.palplot(sns.dark_palette("#ffe34d", n_colors=10),size=1.5)
sns.palplot(sns.blend_palette(("grey","#ffe34d"), n_colors=10),size=1.5)

# %%
sns.palplot(sns.blend_palette(("#ffe34d","#4daf4a","#4575b4","#984ea3","#d73027"), n_colors=20))
sns.palplot(sns.blend_palette(("#ffe34d","#4daf4a","#4575b4"), n_colors=20))
sns.palplot(sns.blend_palette(("#4575b4","#984ea3","#d73027"), n_colors=20))

# %%
sns.palplot(sns.blend_palette(("#d73027","darkorange"), n_colors=6),size=2)
sns.palplot(sns.blend_palette(("darkorange","#ffe34d"), n_colors=6),size=2)
sns.palplot(sns.blend_palette(("#ffe34d","#4daf4a"), n_colors=7),size=2)
sns.palplot(sns.blend_palette(("#4daf4a","#4575b4"), n_colors=6),size=2)
sns.palplot(sns.blend_palette(("#4575b4","#984ea3"), n_colors=6),size=2)
sns.palplot(sns.blend_palette(("#984ea3","#d73027"), n_colors=6),size=2)

# %%
sns.palplot(sns.blend_palette(("#984ea3","black","#d73027"),n_colors=6),size=2)

# %%
sns.palplot(sns.blend_palette(("#d73027","#4daf4a"), n_colors=9),size=2)
sns.palplot(sns.blend_palette(("darkorange","#4575b4"), n_colors=9),size=2)
sns.palplot(sns.blend_palette(("#ffe34d","#984ea3"), n_colors=9),size=2)

# %%
sns.palplot(sns.blend_palette(("#333333","#4575b4","#eeeeee"), n_colors=50))
sns.palplot(sns.blend_palette(("#333333","#d73027","#eeeeee"), n_colors=50))

# %%
sns.palplot(sns.blend_palette(("#4daf4a","#984ea3"), n_colors=7),size=2)
sns.palplot(sns.blend_palette(("#6e6e6e","#984ea3"), n_colors=11),size=2)

# %%
sns.palplot(sns.blend_palette(('salmon',"#984ea3","#4daf4a","#ffe34d"), n_colors=11),size=2)

test = sns.blend_palette(('salmon',"#984ea3","#4daf4a","#ffe34d"), n_colors=11)
this_color = test[3]

this_color
# Out:
# array([0.63677047, 0.3266436 , 0.61886967, 1.        ])

# %%
sns.palplot(sns.blend_palette(('salmon',"#984ea3","#4daf4a","#ffe34d",'darkorange'), n_colors=17),size=2)

# %%
sns.palplot(sns.blend_palette(("black","#984ea3","#4575b4","#4daf4a","#ffe34d","darkorange"), n_colors=21), size=2)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
cmap = sns.blend_palette(("black","#984ea3","#4575b4","#4daf4a","#ffe34d","darkorange"), n_colors=21, as_cmap=True)
cmap.set_over((1., 0., 0.))
cmap.set_under((0., 0., 1.))

norm = mpl.colors.Normalize(vmin=-4, vmax=1)

fig = plt.figure(figsize=(8, 3))
ax = fig.add_axes([0.05, 0.15, 0.9, 0.15])
cb3 = mpl.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                boundaries=[-10] + bounds + [10],
                                extend='both',
                                # Make the length of each extension
                                # the same as the length of the
                                # interior colors:
                                extendfrac='auto',
                                ticks=bounds,
                                spacing='uniform',
                                orientation='horizontal')
cb3.set_label('Custom extension lengths, some other units')

plt.show()

# %%
from matplotlib.colors import LinearSegmentedColormap

def grayscale_cmap(cmap):
    """Return a grayscale version of the given colormap"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    # convert RGBA to perceived grayscale luminance
    # cf. http://alienryderflex.com/hsp.html
    RGB_weight = [0.299, 0.587, 0.114]
    luminance = np.sqrt(np.dot(colors[:, :3] ** 2, RGB_weight))
    colors[:, :3] = luminance[:, np.newaxis]
        
    return LinearSegmentedColormap.from_list(cmap.name + "_gray", colors, cmap.N)
    

def view_colormap(cmap):
    """Plot a colormap with its grayscale equivalent"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    cmap = grayscale_cmap(cmap)
    grayscale = cmap(np.arange(cmap.N))
    
    fig, ax = plt.subplots(2, figsize=(6, 2),
                           subplot_kw=dict(xticks=[], yticks=[]))
    ax[0].imshow([colors], extent=[0, 10, 0, 1])
    ax[1].imshow([grayscale], extent=[0, 10, 0, 1])

# %%
cmap = sns.blend_palette(("black","#984ea3","#4575b4","#4daf4a","#ffe34d","darkorange"), n_colors=21, as_cmap=True)
temperature_color_map = sns.blend_palette(("black","#d73027","darkorange","#ffe34d"), n_colors=50, as_cmap=True)
density_color_map = sns.blend_palette(("black","#984ea3","#d73027","darkorange","#ffe34d","#4daf4a","white"), n_colors=60, as_cmap=True)

view_colormap(density_color_map)

# %%
np.linspace(start=-4, stop=np.log10(3), num=21)
# Out:
# array([-4.        , -3.77614394, -3.55228787, -3.32843181, -3.10457575,
#        -2.88071969, -2.65686362, -2.43300756, -2.2091515 , -1.98529544,
#        -1.76143937, -1.53758331, -1.31372725, -1.08987118, -0.86601512,
#        -0.64215906, -0.418303  , -0.19444693,  0.02940913,  0.25326519,
#         0.47712125])

# %%
# Out:
# 0.47712125471966244
