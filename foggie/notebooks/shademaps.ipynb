# %%
import os
os.sys.path.insert(0, '/Users/molly/Dropbox/foggie/foggie')
import shade_maps as sm
# Out:
# /Users/molly/anaconda3/envs/astroconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/molly/anaconda3/envs/astroconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/molly/anaconda3/envs/astroconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/molly/anaconda3/envs/astroconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# ...

# %%
sm.simple_plot('RD0020/RD0020', 'halo_track', 'x', 'cell_mass', 'phase', ( (0,99), (0,7) ), 'RD0020_natural_position_cell_mass_phase' )
# Out:
# yt : [INFO     ] 2018-09-28 15:09:21,552 Parameters: current_time              = 154.80118773327
# yt : [INFO     ] 2018-09-28 15:09:21,553 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2018-09-28 15:09:21,553 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-09-28 15:09:21,554 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2018-09-28 15:09:21,555 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2018-09-28 15:09:21,556 Parameters: current_redshift          = 1.9999976253354
# yt : [INFO     ] 2018-09-28 15:09:21,556 Parameters: omega_lambda              = 0.715
# yt : [INFO     ] 2018-09-28 15:09:21,557 Parameters: omega_matter              = 0.285
# yt : [INFO     ] 2018-09-28 15:09:21,557 Parameters: hubble_constant           = 0.695
# Parsing Hierarchy : 100%|██████████| 1449/1449 [00:00<00:00, 31093.08it/s]
# ...
