# %%
from astropy.io import ascii


DD_redshift = {}
for halo in ['8508', '4123', '5016', '2392', '2878', '5036']:
    if halo == '8508': haloname = halo
    else: haloname = '5016'
    halo_c_v = ascii.read('/Users/rsimons/Dropbox/git/foggie/foggie/halo_infos/00%s/nref11c_nref9f/halo_c_v'%haloname)

    DD_redshift[halo] = {}
    for rw in halo_c_v:
        DD_redshift[halo][rw['col3']] = rw['col2']
np.save('/Users/rsimons/Dropbox/foggie/catalogs/DD_redshift.npy', DD_redshift)

# %%
halo_c_v
# Out:
# <Table length=512>
#  col1       col2       col3  ...        col8                col9        col10
# int64      str15       str6  ...       str18               str19        int64
# ----- --------------- ------ ... ------------------ ------------------- -----
#    --        redshift   name ...                 yv                  zv    --
#    -- 2.9999997541609 RD0016 ... 160.73178697867885 -108.27182407341665    --
#    -- 2.8079478016887 DD0398 ...  171.0538343719008 -106.72170892495627    --
#    -- 2.8020533632479 DD0399 ... 171.73904039112048 -125.32564295787324    --
#    -- 2.7961810885899 DD0400 ... 170.74460077473162 -142.30869667377098    --
#    --  2.790330842939 DD0401 ...  166.4429006782201 -134.18158955559423    --
#    -- 2.7845024926427 DD0402 ...  164.1527535175895 -114.54841467459283    --
#    --   2.77869590516 DD0403 ... 165.60460702115375 -114.59325634081111    --
#    -- 2.7729109490496 DD0404 ...  165.2188788852182  -124.7851505452845    --
# ...
